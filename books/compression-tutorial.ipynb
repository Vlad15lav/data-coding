# %%
# !git clone https://github.com/Vlad15lav/Data-Compression.git
# Out:
# Cloning into 'Data-Compression'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 54 (delta 23), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (54/54), done.

# %%
# %cd Data-Compression/
# Out:
# /content/Data-Compression

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 81kB 2.7MB/s
# ...
#   Created wheel for bitarray: filename=bitarray-2.2.1-cp37-cp37m-linux_x86_64.whl size=157381 sha256=dbb7e3d76667cc417ce32267b61e5f4995a380750d5a172584a386cd2e1af865
#   Stored in directory: /root/.cache/pip/wheels/b5/22/95/302ef169bfdb8509114a6daafa7232098acf79d09e0ebcdcaf
# Successfully built bitarray
# ...

# %%
# !ls
# Out:
# main.py  README.md  requirements.txt  utils

# %%
# !mkdir files
# %cd files
# !wget http://www.africau.edu/images/default/sample.pdf
# %cd ..
# Out:
# /content/Data-Compression/files
# --2021-07-09 07:38:00--  http://www.africau.edu/images/default/sample.pdf
# Resolving www.africau.edu (www.africau.edu)... 172.67.148.215, 104.21.63.175, 2606:4700:3037::6815:3faf, ...
# Connecting to www.africau.edu (www.africau.edu)|172.67.148.215|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3028 (3.0K) [application/pdf]
# Saving to: ‘sample.pdf’
#
# sample.pdf          100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2021-07-09 07:38:01 (409 MB/s) - ‘sample.pdf’ saved [3028/3028]
#
# /content/Data-Compression

# %%
# !python main.py --help
# Out:
# usage: Data-Compression - Vlad15lav [-h] [-f FILE] [-s SAVE] [--type TYPE]
#                                     [-c] [-d] [--max_length MAX_LENGTH]
#                                     [--max_offset MAX_OFFSET]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f FILE, --file FILE  path file
#   -s SAVE, --save SAVE  path save file
#   --type TYPE           name data compression algorithm
#   -c, --compress        compression mode
#   -d, --decompress      decompression mode
#   --max_length MAX_LENGTH
#                         max length pattern
#   --max_offset MAX_OFFSET
#                         max offset in buffer

# %%
# !python main.py -f files/sample.pdf -s files/sample.bin --type LZ77 --compress

# %%
# !python main.py -f files/sample.bin -s files/copy_sample.pdf --type LZ77 --decompress

# %%
# !ls -l files
# Out:
# total 12
# -rw-r--r-- 1 root root 3029 Jul  9 07:38 copy_sample.pdf
# -rw-r--r-- 1 root root 1733 Jul  9 07:38 sample.bin
# -rw-r--r-- 1 root root 3028 Feb 24  2017 sample.pdf

# %%
# !python main.py -f files/sample.pdf -s files/sample.bin --type LZ78 --compress

# %%
# !python main.py -f files/sample.bin -s files/copy_sample.pdf --type LZ78 --decompress

# %%
# !ls -l files
# Out:
# total 12
# -rw-r--r-- 1 root root 3028 Jul  9 07:38 copy_sample.pdf
# -rw-r--r-- 1 root root 1900 Jul  9 07:38 sample.bin
# -rw-r--r-- 1 root root 3028 Feb 24  2017 sample.pdf
